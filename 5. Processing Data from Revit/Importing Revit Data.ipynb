# %%
# !pip install pandas openpyxl

# %%
import pandas as pd

# Replace 'your_file.xlsx' with the path to your Excel file
df = pd.read_excel('ExportRevit.xlsx')

# Display the first few rows of the DataFrame
print(df.head())
